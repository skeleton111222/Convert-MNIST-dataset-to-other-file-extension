# %% [markdown]
# <a href="https://colab.research.google.com/github/skeleton111222/Convert-MNIST-dataset-to-other-file-extension/blob/main/Convert_MNIST_dataset_to_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **json**

# %%
from tensorflow.keras.datasets import mnist
import json

(x_train, y_train), _ = mnist.load_data()

data = []
for i in range(100):  # START SMALL (100 images)
    data.append({
        "label": int(y_train[i]),
        "pixels": x_train[i].flatten().tolist()
    })

with open("mnist_small.json", "w") as f:
    json.dump(data, f)

print("Saved mnist_small.json")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Saved mnist_small.json

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0], cmap="gray")
plt.title(f"Label: {y_train[0]}")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
